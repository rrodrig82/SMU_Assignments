# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint
import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
requests.get(link+"kodiak").json()
# Out:
# {'coord': {'lon': -94.76, 'lat': 39.95},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 67.78,
#   'pressure': 1011,
#   'humidity': 68,
#   'temp_min': 64.4,
#   'temp_max': 71.6},
#  'visibility': 16093,
#  'wind': {'speed': 9.17, 'deg': 140},
#  'clouds': {'all': 1},
#  'dt': 1569546459,
#  'sys': {'type': 1,
#   'id': 4042,
#   'message': 0.0067,
#   'country': 'US',
#   'sunrise': 1569499812,
#   'sunset': 1569543036},
#  'timezone': -18000,
#  'id': 4407665,
#  'name': 'Kodiak',
#  'cod': 200}

# %%
link = "https://api.openweathermap.org/data/2.5/weather?"
link = f"{link}appid={api_key}&units=imperial&q="

#set up lists hold data

location = []
clouds = []
country = []
date = []
humidity = []
lats = []
lngs = []
max_temp = []
wind = []

#set orgainizational variables
count = 0
current_set = 1

#collect data and store in lists
print("Beginning Data Retrieval\n-----------------------------")
for city in cities:
   try:
       data = requests.get(link+city).json()
       location.append(data["name"])
       clouds.append(data["clouds"]["all"])
       country.append(data["sys"]["country"])
       date.append(datetime.date.fromtimestamp(data["dt"]))
       humidity.append(data["main"]["humidity"])
       lats.append(data["coord"]["lat"])
       lngs.append(data["coord"]["lon"])
       max_temp.append(data["main"]["temp_max"])
       wind.append(data["wind"]["speed"])
       if count > 49:
           count = 1
           current_set += 1
       else:
           count += 1
       print(f"Processing record {count} of set {current_set} | {city}")
   except Exception:
       print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 1 of set 1 | samarai
# City not found. Skipping...
# Processing record 2 of set 1 | punta arenas
# Processing record 3 of set 1 | dukat
# City not found. Skipping...
# Processing record 4 of set 1 | ahipara
# Processing record 5 of set 1 | hermanus
# Processing record 6 of set 1 | nochistlan
# Processing record 7 of set 1 | esperance
# City not found. Skipping...
# Processing record 8 of set 1 | bluff
# Processing record 9 of set 1 | mataura
# Processing record 10 of set 1 | kloulklubed
# Processing record 11 of set 1 | bulgan
# Processing record 12 of set 1 | mar del plata
# Processing record 13 of set 1 | cayenne
# Processing record 14 of set 1 | saint-philippe
# City not found. Skipping...
# City not found. Skipping...
# Processing record 15 of set 1 | cape town
# Processing record 16 of set 1 | port alfred
# Processing record 17 of set 1 | acajutla
# Processing record 18 of set 1 | ribeira grande
# Processing record 19 of set 1 | atuona
# Processing record 20 of set 1 | alice springs
# Processing record 21 of set 1 | tasiilaq
# Processing record 22 of set 1 | albany
# City not found. Skipping...
# Processing record 23 of set 1 | hamilton
# Processing record 24 of set 1 | tuktoyaktuk
# City not found. Skipping...
# Processing record 25 of set 1 | hilo
# Processing record 26 of set 1 | rikitea
# Processing record 27 of set 1 | severo-kurilsk
# Processing record 28 of set 1 | avarua
# Processing record 29 of set 1 | longyearbyen
# Processing record 30 of set 1 | abancay
# Processing record 31 of set 1 | bredasdorp
# Processing record 32 of set 1 | chokurdakh
# Processing record 33 of set 1 | manokwari
# Processing record 34 of set 1 | port elizabeth
# Processing record 35 of set 1 | carmelo
# Processing record 36 of set 1 | fortuna
# Processing record 37 of set 1 | salalah
# Processing record 38 of set 1 | inhambane
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing record 39 of set 1 | isangel
# Processing record 40 of set 1 | te anau
# Processing record 41 of set 1 | starobachaty
# City not found. Skipping...
# Processing record 42 of set 1 | belomorsk
# Processing record 43 of set 1 | thompson
# Processing record 44 of set 1 | puerto madero
# Processing record 45 of set 1 | nuuk
# Processing record 46 of set 1 | comodoro rivadavia
# Processing record 47 of set 1 | rognan
# Processing record 48 of set 1 | castro
# Processing record 49 of set 1 | inhapim
# Processing record 50 of set 1 | pandan
# Processing record 1 of set 2 | lorengau
# Processing record 2 of set 2 | coahuayana
# City not found. Skipping...
# Processing record 3 of set 2 | hithadhoo
# Processing record 4 of set 2 | faanui
# Processing record 5 of set 2 | yellowknife
# Processing record 6 of set 2 | bethel
# Processing record 7 of set 2 | pochutla
# Processing record 8 of set 2 | vaini
# Processing record 9 of set 2 | busselton
# Processing record 10 of set 2 | hobart
# Processing record 11 of set 2 | normandin
# City not found. Skipping...
# Processing record 12 of set 2 | ust-kut
# City not found. Skipping...
# Processing record 13 of set 2 | qaanaaq
# Processing record 14 of set 2 | guerrero negro
# Processing record 15 of set 2 | cabo san lucas
# Processing record 16 of set 2 | acapulco
# Processing record 17 of set 2 | ushuaia
# City not found. Skipping...
# Processing record 18 of set 2 | fort nelson
# Processing record 19 of set 2 | kavaratti
# Processing record 20 of set 2 | rio grande
# Processing record 21 of set 2 | jamestown
# Processing record 22 of set 2 | svencioneliai
# Processing record 23 of set 2 | hobyo
# Processing record 24 of set 2 | suntar
# Processing record 25 of set 2 | khatanga
# City not found. Skipping...
# Processing record 26 of set 2 | vila
# Processing record 27 of set 2 | alofi
# Processing record 28 of set 2 | zhigansk
# City not found. Skipping...
# Processing record 29 of set 2 | laguna
# Processing record 30 of set 2 | puerto ayora
# Processing record 31 of set 2 | faya
# Processing record 32 of set 2 | port lincoln
# Processing record 33 of set 2 | biltine
# Processing record 34 of set 2 | nemuro
# City not found. Skipping...
# Processing record 35 of set 2 | norman wells
# Processing record 36 of set 2 | pangody
# Processing record 37 of set 2 | lompoc
# Processing record 38 of set 2 | nhulunbuy
# Processing record 39 of set 2 | port hedland
# Processing record 40 of set 2 | albacete
# City not found. Skipping...
# Processing record 41 of set 2 | hokitika
# Processing record 42 of set 2 | cahabon
# City not found. Skipping...
# Processing record 43 of set 2 | issoudun
# Processing record 44 of set 2 | yar-sale
# Processing record 45 of set 2 | half moon bay
# Processing record 46 of set 2 | kapaa
# Processing record 47 of set 2 | new norfolk
# Processing record 48 of set 2 | kodiak
# Processing record 49 of set 2 | itacarambi
# Processing record 50 of set 2 | yulara
# Processing record 1 of set 3 | meybod
# Processing record 2 of set 3 | hay river
# Processing record 3 of set 3 | pallasovka
# City not found. Skipping...
# Processing record 4 of set 3 | upernavik
# Processing record 5 of set 3 | klaksvik
# Processing record 6 of set 3 | tezu
# Processing record 7 of set 3 | george
# Processing record 8 of set 3 | narsaq
# Processing record 9 of set 3 | seoul
# Processing record 10 of set 3 | sibay
# Processing record 11 of set 3 | shahganj
# Processing record 12 of set 3 | pangnirtung
# Processing record 13 of set 3 | dikson
# Processing record 14 of set 3 | pevek
# Processing record 15 of set 3 | lebanon
# Processing record 16 of set 3 | berlevag
# Processing record 17 of set 3 | komsomolskiy
# Processing record 18 of set 3 | biak
# Processing record 19 of set 3 | cidreira
# Processing record 20 of set 3 | butaritari
# Processing record 21 of set 3 | tiksi
# Processing record 22 of set 3 | yangambi
# Processing record 23 of set 3 | kavieng
# Processing record 24 of set 3 | padang
# Processing record 25 of set 3 | fairbanks
# City not found. Skipping...
# City not found. Skipping...
# Processing record 26 of set 3 | kaitangata
# Processing record 27 of set 3 | sapatgram
# Processing record 28 of set 3 | hartselle
# Processing record 29 of set 3 | lebu
# Processing record 30 of set 3 | virginia beach
# Processing record 31 of set 3 | aljezur
# Processing record 32 of set 3 | corn island
# Processing record 33 of set 3 | provideniya
# Processing record 34 of set 3 | mandali
# Processing record 35 of set 3 | katsuura
# Processing record 36 of set 3 | redmond
# Processing record 37 of set 3 | torbay
# Processing record 38 of set 3 | sumbe
# City not found. Skipping...
# City not found. Skipping...
# Processing record 39 of set 3 | saint george
# Processing record 40 of set 3 | gat
# City not found. Skipping...
# Processing record 41 of set 3 | geraldton
# City not found. Skipping...
# Processing record 42 of set 3 | hasaki
# Processing record 43 of set 3 | kununurra
# Processing record 44 of set 3 | paita
# Processing record 45 of set 3 | urengoy
# Processing record 46 of set 3 | ancud
# Processing record 47 of set 3 | les cayes
# Processing record 48 of set 3 | deputatskiy
# Processing record 49 of set 3 | carnarvon
# Processing record 50 of set 3 | shuangcheng
# Processing record 1 of set 4 | yopal
# Processing record 2 of set 4 | nanortalik
# Processing record 3 of set 4 | victoria
# Processing record 4 of set 4 | saint-augustin
# Processing record 5 of set 4 | sitka
# Processing record 6 of set 4 | barrow
# Processing record 7 of set 4 | constitucion
# Processing record 8 of set 4 | longhua
# Processing record 9 of set 4 | lubao
# Processing record 10 of set 4 | proddatur
# Processing record 11 of set 4 | ponta do sol
# Processing record 12 of set 4 | kautokeino
# City not found. Skipping...
# Processing record 13 of set 4 | avila
# Processing record 14 of set 4 | dmitriyevka
# Processing record 15 of set 4 | arraial do cabo
# Processing record 16 of set 4 | kangaatsiaq
# Processing record 17 of set 4 | barstow
# Processing record 18 of set 4 | dingle
# Processing record 19 of set 4 | port macquarie
# City not found. Skipping...
# City not found. Skipping...
# Processing record 20 of set 4 | churapcha
# Processing record 21 of set 4 | taoudenni
# Processing record 22 of set 4 | coxim
# Processing record 23 of set 4 | ixtapa
# City not found. Skipping...
# Processing record 24 of set 4 | codrington
# Processing record 25 of set 4 | itoman
# City not found. Skipping...
# Processing record 26 of set 4 | celestun
# Processing record 27 of set 4 | parkersburg
# Processing record 28 of set 4 | idaho falls
# Processing record 29 of set 4 | santa maria
# Processing record 30 of set 4 | east london
# Processing record 31 of set 4 | la ronge
# Processing record 32 of set 4 | tomakivka
# Processing record 33 of set 4 | bhavnagar
# City not found. Skipping...
# Processing record 34 of set 4 | lazaro cardenas
# City not found. Skipping...
# Processing record 35 of set 4 | lanzhou
# Processing record 36 of set 4 | neiafu
# Processing record 37 of set 4 | plettenberg bay
# Processing record 38 of set 4 | escanaba
# Processing record 39 of set 4 | riyadh
# Processing record 40 of set 4 | airai
# Processing record 41 of set 4 | saskylakh
# Processing record 42 of set 4 | gondanglegi
# Processing record 43 of set 4 | sao filipe
# Processing record 44 of set 4 | saint-joseph
# Processing record 45 of set 4 | shahr-e kord
# Processing record 46 of set 4 | touros
# Processing record 47 of set 4 | souillac
# Processing record 48 of set 4 | haines junction
# Processing record 49 of set 4 | beringovskiy
# Processing record 50 of set 4 | gopalpur
# Processing record 1 of set 5 | puerto madryn
# Processing record 2 of set 5 | moussoro
# Processing record 3 of set 5 | chumphon
# Processing record 4 of set 5 | kuybysheve
# Processing record 5 of set 5 | kapuskasing
# Processing record 6 of set 5 | mahebourg
# Processing record 7 of set 5 | kruisfontein
# Processing record 8 of set 5 | iqaluit
# City not found. Skipping...
# Processing record 9 of set 5 | glushkovo
# City not found. Skipping...
# Processing record 10 of set 5 | aykhal
# Processing record 11 of set 5 | adrar
# Processing record 12 of set 5 | ossora
# Processing record 13 of set 5 | jaciara
# Processing record 14 of set 5 | sapouy
# Processing record 15 of set 5 | verkhnevilyuysk
# Processing record 16 of set 5 | nikolskoye
# Processing record 17 of set 5 | bambous virieux
# Processing record 18 of set 5 | durant
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing record 19 of set 5 | aurdal
# Processing record 20 of set 5 | shache
# Processing record 21 of set 5 | berea
# Processing record 22 of set 5 | tuatapere
# Processing record 23 of set 5 | takapau
# Processing record 24 of set 5 | brigantine
# Processing record 25 of set 5 | vostochnyy
# Processing record 26 of set 5 | paharpur
# Processing record 27 of set 5 | broome
# Processing record 28 of set 5 | clarence town
# Processing record 29 of set 5 | bolshaya glushitsa
# Processing record 30 of set 5 | mount darwin
# Processing record 31 of set 5 | angoram
# Processing record 32 of set 5 | segou
# Processing record 33 of set 5 | camacha
# City not found. Skipping...
# Processing record 34 of set 5 | bilibino
# Processing record 35 of set 5 | yeppoon
# Processing record 36 of set 5 | sambava
# Processing record 37 of set 5 | leningradskiy
# Processing record 38 of set 5 | qaqortoq
# Processing record 39 of set 5 | tarauaca
# Processing record 40 of set 5 | thinadhoo
# Processing record 41 of set 5 | knysna
# Processing record 42 of set 5 | hovd
# Processing record 43 of set 5 | alta floresta
# Processing record 44 of set 5 | livny
# Processing record 45 of set 5 | japura
# Processing record 46 of set 5 | makakilo city
# Processing record 47 of set 5 | pimenta bueno
# Processing record 48 of set 5 | aksarka
# Processing record 49 of set 5 | ahmadpur east
# City not found. Skipping...
# City not found. Skipping...
# Processing record 50 of set 5 | chalchihuites
# Processing record 1 of set 6 | ketchikan
# Processing record 2 of set 6 | bako
# Processing record 3 of set 6 | cherskiy
# Processing record 4 of set 6 | san luis
# Processing record 5 of set 6 | siguiri
# Processing record 6 of set 6 | kasongo
# Processing record 7 of set 6 | kungurtug
# Processing record 8 of set 6 | the valley
# Processing record 9 of set 6 | sao joao da barra
# City not found. Skipping...
# Processing record 10 of set 6 | kharan
# Processing record 11 of set 6 | jining
# Processing record 12 of set 6 | morgan city
# Processing record 13 of set 6 | fasa
# Processing record 14 of set 6 | san jose
# Processing record 15 of set 6 | tiznit
# Processing record 16 of set 6 | sicamous
# Processing record 17 of set 6 | yining
# Processing record 18 of set 6 | verkhnyaya inta
# Processing record 19 of set 6 | atambua
# Processing record 20 of set 6 | pisco
# Processing record 21 of set 6 | port hardy
# Processing record 22 of set 6 | ngunguru
# City not found. Skipping...
# Processing record 23 of set 6 | praxedis guerrero
# Processing record 24 of set 6 | chino valley
# Processing record 25 of set 6 | pipri
# Processing record 26 of set 6 | darnah
# Processing record 27 of set 6 | namibe
# City not found. Skipping...
# Processing record 28 of set 6 | keetmanshoop
# Processing record 29 of set 6 | sundumbili
# Processing record 30 of set 6 | kutum
# Processing record 31 of set 6 | chuy
# Processing record 32 of set 6 | tuntange
# Processing record 33 of set 6 | katra
# Processing record 34 of set 6 | cockburn town
# Processing record 35 of set 6 | sohbatpur
# Processing record 36 of set 6 | edd
# Processing record 37 of set 6 | moerai
# Processing record 38 of set 6 | minas de barroteran
# Processing record 39 of set 6 | stephenville
# City not found. Skipping...
# Processing record 40 of set 6 | calbuco
# Processing record 41 of set 6 | plouzane
# Processing record 42 of set 6 | leh
# Processing record 43 of set 6 | yumen
# Processing record 44 of set 6 | acari
# Processing record 45 of set 6 | saint anthony
# City not found. Skipping...
# City not found. Skipping...
# Processing record 46 of set 6 | gambo
# Processing record 47 of set 6 | otjiwarongo
# Processing record 48 of set 6 | palmer
# Processing record 49 of set 6 | bria
# City not found. Skipping...
# Processing record 50 of set 6 | wanning
# Processing record 1 of set 7 | vanavara
# City not found. Skipping...
# Processing record 2 of set 7 | vestmannaeyjar
# Processing record 3 of set 7 | tommot
# Processing record 4 of set 7 | zyryanka
# Processing record 5 of set 7 | lasa
# Processing record 6 of set 7 | poltavka
# Processing record 7 of set 7 | jardim
# Processing record 8 of set 7 | hualmay
# Processing record 9 of set 7 | siparia
# Processing record 10 of set 7 | poli
# Processing record 11 of set 7 | anadyr
# Processing record 12 of set 7 | vares
# Processing record 13 of set 7 | dezhou
# Processing record 14 of set 7 | jalu
# Processing record 15 of set 7 | dolores
# Processing record 16 of set 7 | timbiqui
# Processing record 17 of set 7 | manado
# Processing record 18 of set 7 | oriximina
# Processing record 19 of set 7 | gold coast
# Processing record 20 of set 7 | chapais
# Processing record 21 of set 7 | georgetown
# Processing record 22 of set 7 | healdsburg
# Processing record 23 of set 7 | bushehr
# Processing record 24 of set 7 | sayyan
# City not found. Skipping...
# Processing record 25 of set 7 | qasigiannguit
# Processing record 26 of set 7 | waipawa
# Processing record 27 of set 7 | limoeiro do ajuru
# Processing record 28 of set 7 | buala
# Processing record 29 of set 7 | khandyga
# Processing record 30 of set 7 | kailua
# City not found. Skipping...
# Processing record 31 of set 7 | talavera
# Processing record 32 of set 7 | viedma
# Processing record 33 of set 7 | vila velha
# Processing record 34 of set 7 | tessalit
# Processing record 35 of set 7 | walvis bay
# Processing record 36 of set 7 | shimoda
# Processing record 37 of set 7 | sovetskiy
# Processing record 38 of set 7 | shenjiamen
# Processing record 39 of set 7 | selje
# Processing record 40 of set 7 | senanga
# Processing record 41 of set 7 | mutata
# Processing record 42 of set 7 | san cristobal
# Processing record 43 of set 7 | lagoa
# Processing record 44 of set 7 | san quintin
# City not found. Skipping...
# Processing record 45 of set 7 | kieta
# Processing record 46 of set 7 | waitara
# City not found. Skipping...
# Processing record 47 of set 7 | chumikan
# City not found. Skipping...
# Processing record 48 of set 7 | nadym
# Processing record 49 of set 7 | surt
# Processing record 50 of set 7 | atar
# City not found. Skipping...
# Processing record 1 of set 8 | alghero
# City not found. Skipping...
# Processing record 2 of set 8 | changtu
# Processing record 3 of set 8 | abu kamal
# Processing record 4 of set 8 | shaoxing
# Processing record 5 of set 8 | luderitz
# Processing record 6 of set 8 | utinga
# Processing record 7 of set 8 | shenzhen
# Processing record 8 of set 8 | chifeng
# City not found. Skipping...
# Processing record 9 of set 8 | molteno
# Processing record 10 of set 8 | zharkovskiy
# City not found. Skipping...
# Processing record 11 of set 8 | antofagasta
# Processing record 12 of set 8 | ghanzi
# City not found. Skipping...
# Processing record 13 of set 8 | chongwe
# Processing record 14 of set 8 | payakumbuh
# Processing record 15 of set 8 | khuzhir
# City not found. Skipping...
# Processing record 16 of set 8 | cankuzo
# Processing record 17 of set 8 | leticia
# Processing record 18 of set 8 | mitchell
# Processing record 19 of set 8 | auki
# Processing record 20 of set 8 | rundu
# Processing record 21 of set 8 | wairoa
# Processing record 22 of set 8 | moron
# Processing record 23 of set 8 | chau doc
# Processing record 24 of set 8 | preobrazheniye
# Processing record 25 of set 8 | sabang
# Processing record 26 of set 8 | zyryanovsk
# Processing record 27 of set 8 | turayf
# Processing record 28 of set 8 | gualeguay
# Processing record 29 of set 8 | roebourne
# Processing record 30 of set 8 | meadow lake
# Processing record 31 of set 8 | praya
# Processing record 32 of set 8 | marawi
# Processing record 33 of set 8 | zhezkazgan
# Processing record 34 of set 8 | powell river
# Processing record 35 of set 8 | kazuno
# Processing record 36 of set 8 | askiz
# Processing record 37 of set 8 | pareora
# Processing record 38 of set 8 | umm lajj
# City not found. Skipping...
# City not found. Skipping...
# Processing record 39 of set 8 | sai buri
# Processing record 40 of set 8 | vestmanna
# Processing record 41 of set 8 | broken hill
# Processing record 42 of set 8 | ladnun
# Processing record 43 of set 8 | ust-ilimsk
# Processing record 44 of set 8 | gizo
# Processing record 45 of set 8 | ojinaga
# Processing record 46 of set 8 | winkler
# Processing record 47 of set 8 | guatire
# Processing record 48 of set 8 | jipijapa
# Processing record 49 of set 8 | pudozh
# Processing record 50 of set 8 | saint-pierre
# Processing record 1 of set 9 | lewiston
# Processing record 2 of set 9 | ostrovnoy
# Processing record 3 of set 9 | khandbari
# City not found. Skipping...
# Processing record 4 of set 9 | tahe
# Processing record 5 of set 9 | meulaboh
# Processing record 6 of set 9 | rio gallegos
# Processing record 7 of set 9 | kyabe
# Processing record 8 of set 9 | carnot
# Processing record 9 of set 9 | neuquen
# Processing record 10 of set 9 | rawson
# Processing record 11 of set 9 | awjilah
# Processing record 12 of set 9 | caravelas
# Processing record 13 of set 9 | salcedo
# Processing record 14 of set 9 | chicama
# Processing record 15 of set 9 | lake city
# Processing record 16 of set 9 | shizunai
# Processing record 17 of set 9 | sortavala
# Processing record 18 of set 9 | marzuq
# City not found. Skipping...
# Processing record 19 of set 9 | ewa beach
# Processing record 20 of set 9 | jieshi
# Processing record 21 of set 9 | challapata
# Processing record 22 of set 9 | manoel urbano
# Processing record 23 of set 9 | husavik
# Processing record 24 of set 9 | shu
# City not found. Skipping...
# Processing record 25 of set 9 | bielsk podlaski
# Processing record 26 of set 9 | scottsbluff
# Processing record 27 of set 9 | havelock
# Processing record 28 of set 9 | sorland
# Processing record 29 of set 9 | nizhniy tsasuchey
# Processing record 30 of set 9 | san rafael
# Processing record 31 of set 9 | dire
# Processing record 32 of set 9 | san julian
# Processing record 33 of set 9 | taltal
# Processing record 34 of set 9 | prince rupert
# Processing record 35 of set 9 | nelson bay
# Processing record 36 of set 9 | teahupoo
# Processing record 37 of set 9 | san-pedro
# Processing record 38 of set 9 | qandala
# Processing record 39 of set 9 | mizdah
# Processing record 40 of set 9 | magole
# Processing record 41 of set 9 | emerald
# Processing record 42 of set 9 | bowen
# City not found. Skipping...
# Processing record 43 of set 9 | portland
# Processing record 44 of set 9 | sorong
# Processing record 45 of set 9 | hefei
# Processing record 46 of set 9 | pozo colorado
# Processing record 47 of set 9 | nyurba
# Processing record 48 of set 9 | harper
# Processing record 49 of set 9 | ponta delgada
# City not found. Skipping...
# Processing record 50 of set 9 | olivenza
# City not found. Skipping...
# Processing record 1 of set 10 | phalombe
# Processing record 2 of set 10 | jega
# Processing record 3 of set 10 | vardo
# City not found. Skipping...
# Processing record 4 of set 10 | brae
# Processing record 5 of set 10 | ponoka
# Processing record 6 of set 10 | aripuana
# Processing record 7 of set 10 | mount isa
# Processing record 8 of set 10 | oranjemund
# Processing record 9 of set 10 | eureka
# Processing record 10 of set 10 | weida
# Processing record 11 of set 10 | fez
# Processing record 12 of set 10 | malaryta
# Processing record 13 of set 10 | sobolevo
# Processing record 14 of set 10 | beian
# Processing record 15 of set 10 | mount gambier
# Processing record 16 of set 10 | almaznyy
# Processing record 17 of set 10 | pyshchug
# Processing record 18 of set 10 | santa marta
# Processing record 19 of set 10 | uvalde
# Processing record 20 of set 10 | aloleng
# Processing record 21 of set 10 | samsun
# Processing record 22 of set 10 | rocha
# Processing record 23 of set 10 | nome
# Processing record 24 of set 10 | tiarei
# City not found. Skipping...
# City not found. Skipping...
# Processing record 25 of set 10 | borogontsy
# City not found. Skipping...
# Processing record 26 of set 10 | ust-kuyga
# Processing record 27 of set 10 | alausi
# Processing record 28 of set 10 | zaigrayevo
# City not found. Skipping...
# Processing record 29 of set 10 | cabedelo
# Processing record 30 of set 10 | andros town
# Processing record 31 of set 10 | peru
# Processing record 32 of set 10 | zatoka
# Processing record 33 of set 10 | igurubi
# Processing record 34 of set 10 | saldanha
# City not found. Skipping...
# Processing record 35 of set 10 | bathsheba
# Processing record 36 of set 10 | connersville
# City not found. Skipping...
# Processing record 37 of set 10 | almenara
# Processing record 38 of set 10 | roman
# Processing record 39 of set 10 | phuket
# Processing record 40 of set 10 | pedasi
# Processing record 41 of set 10 | huilong
# Processing record 42 of set 10 | avera
# Processing record 43 of set 10 | poum
# City not found. Skipping...
# Processing record 44 of set 10 | vagay
# Processing record 45 of set 10 | rincon
# Processing record 46 of set 10 | innisfail
# Processing record 47 of set 10 | vao
# Processing record 48 of set 10 | oranjestad
# Processing record 49 of set 10 | sault sainte marie
# Processing record 50 of set 10 | hambantota
# Processing record 1 of set 11 | nueve de julio
# Processing record 2 of set 11 | charlottetown
# Processing record 3 of set 11 | enid
# Processing record 4 of set 11 | beloha
# Processing record 5 of set 11 | rafaela
# City not found. Skipping...
# Processing record 6 of set 11 | certegui
# City not found. Skipping...
# Processing record 7 of set 11 | pasni
# Processing record 8 of set 11 | winnemucca
# City not found. Skipping...
# Processing record 9 of set 11 | amarante
# Processing record 10 of set 11 | kidal
# Processing record 11 of set 11 | mocorito
# Processing record 12 of set 11 | ambovombe
# Processing record 13 of set 11 | havre-saint-pierre
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = {"City": location,
     "Cloudiness": clouds,
     "Country": country,
     "Date": date,
     "Humidity": humidity,
     "Latitude": lats,
     "Longitude": lngs,
     "Max Temperature": max_temp,
     "Wind Speed": wind
}

#convert to dataframe
df = pd.DataFrame(df)
df.count()
# Out:
# City               513
# Cloudiness         513
# Country            513
# Date               513
# Humidity           513
# Latitude           513
# Longitude          513
# Max Temperature    513
# Wind Speed         513
# dtype: int64

# %%
df.to_csv("../output_data/weather_data.csv")
df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity  Latitude  \
# 0       Samarai          96      PG  2019-09-26        92    -10.62
# 1  Punta Arenas           0      CL  2019-09-26        45    -53.16
# 2         Dukat          44      AL  2019-09-26        91     40.25
# 3       Ahipara          70      NZ  2019-09-26        71    -35.17
# 4      Hermanus           0      ZA  2019-09-26        48    -34.42
#
#    Longitude  Max Temperature  Wind Speed
# 0     150.67            76.12        6.71
# 1     -70.91            48.20       16.11
# 2      19.57            71.01        3.00
# 3     173.16            66.99       19.77
# 4      19.24            72.00        5.64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#create a plot based on latitude and max temp
fig, ax = plt.subplots(figsize=(15,10))
ax.scatter(x=df["Latitude"], y=df["Max Temperature"])
#label graph
plt.title("Correlation of Latituted and Maximum Temperature", size=15)
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (Celcius)")
plt.grid()
#save as png
plt.savefig("../output_data/temp_scatter")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.scatter(x=df["Latitude"], y=df["Humidity"])
#label graph
plt.title("Latitude vs. Humidity", size=15)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
#save as png
plt.savefig("../output_data/humidity_scatter")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.scatter(x=df["Latitude"], y=df["Cloudiness"])
#label graph
plt.title("Latitude vs. Cloudiness", size=15)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
#save as png
plt.savefig("../output_data/clooudiness_scatter")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.scatter(x=df["Latitude"], y=df["Wind Speed"])
#label graph
plt.title("Latitude vs. Wind", size=15)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
#save as png
plt.savefig("../output_data/wind_scatter")
